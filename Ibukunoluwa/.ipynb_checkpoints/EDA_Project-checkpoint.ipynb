# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df_cities = pd.read_csv("C:\Users\HP\Desktop\Hamoye Data Science Internship  Materials\Premier Project\Historical-Hourly-Weather-Data\Dataset\city_")
